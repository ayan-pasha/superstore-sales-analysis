# %%
print("hello Ayan")
# Out:
# hello Ayan

# %%
print(" I am a Data Analyst")
# Out:
#  I am a Data Analyst

# %%
print(100+200)
# Out:
# 300

# %%
print(1000-350)
# Out:
# 650

# %%
print(10*5)
# Out:
# 50

# %%
name="Ayan"
print(name)
# Out:
# Ayan

# %%
age=25
print(age)
# Out:
# 25

# %%
salary=50000
print("my salary is", salary)
print("my age is", age)
print("my name is", name, )
# Out:
# my salary is 50000
# my age is 25
# my name is Ayan

# %%
city="Dubai"
cities=["Dubai", "Abu Dhabi", "Sharjah"]

# %%
cities=["Dubai", "Abu Dhabi", "Sharjah", "Ajman"]
print(cities)
# Out:
# ['Dubai', 'Abu Dhabi', 'Sharjah', 'Ajman']

# %%
sales=[1000, 1500, 2000, 2500  ]
print(sales)
# Out:
# [1000, 1500, 2000, 2500]

# %%
total =sum(sales)
print("total sales is", total)
# Out:
# total sales is 7000

# %%
print("Heighest sales is", max(sales))
print("Lowest sales is", min(sales))
# Out:
# Heighest sales is 2500
# Lowest sales is 1000

# %%
name="Ayan"
region="Dubai"

sales=[1000, 1500, 2000, 2500  ]
total_sales =sum(sales)
highest_sales =max(sales)
lowest_sales = min(sales)
average_sales = total_sales / len(sales)
 
print("analyst:", name)
print("region:", region)
print("total sales:", total_sales)
print("highest sales:", highest_sales)
print("lowest sales:", lowest_sales)
print("Average sales:", average_sales)
# Out:
# analyst: Ayan
# region: Dubai
# total sales: 7000
# highest sales: 2500
# lowest sales: 1000
# Average sales: 1750.0

# %%
sales= 2500

if sales>2000:
    print("Good performance!"  )
else:
    print("Needs improvement.")
# Out:
# Good performance!

# %%
sales= 1000

if sales>2000:
    print("Good performance!"  )
else:
    print("Needs improvement.")
# Out:
# Needs improvement.

# %%
name = "Ayan"
region = "Dubai"
sales = [1000, 1500, 2000, 2500]    
total_sales = sum(sales)
highest_sales = max(sales)    
lowest_sales = min(sales)
average_sales = total_sales / len(sales)    
print("Analyst:", name)
print("Region:", region) 
print("Total Sales:", total_sales)
print("Highest Sales:", highest_sales)
print("Lowest Sales:", lowest_sales)
print("Average Sales:", average_sales)

if average_sales > 2000:
    print("Good performance!")
else:
    print("Needs improvement.")
    if average_sales > 1500:
        print("Average performance.")   
    else:
        print(" performance:Needs improvement")
# Out:
# Analyst: Ayan
# Region: Dubai
# Total Sales: 7000
# Highest Sales: 2500
# Lowest Sales: 1000
# Average Sales: 1750.0
# Needs improvement.
# Average performance.
